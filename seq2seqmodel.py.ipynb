# %%
from recurrentshop import *
from keras.layers import *
from keras.models import Model
import seq2seq
# Out:
# Using TensorFlow backend.

# %%
import seq2seq
from seq2seq.models import SimpleSeq2Seq

model = SimpleSeq2Seq(input_dim=5, hidden_dim=10, output_length=8, output_dim=8, depth=3)
model.compile(loss='mse', optimizer='rmsprop')
# Out:
# Using TensorFlow backend.

# %%
import pandas as pd

# %%
df = pd.read_csv('AHMADNAGAR.csv')

# %%
df
# Out:
#                                                QueryText  \
# 0                         Asking about weather forecast?
# 1                         Asking about weather forecast?
# 2                         Asking about weather forecast?
# 3                         Asking about weather forecast?
# 4                    ASKING ABOUT WEATHER REPORT TAHSIL?
# 5                    ASKING ABOUT WEATHER REPORT TAHSIL?
# 6                         Asking about weather forecast?
# 7                         Asking about weather forecast?
# 8                        Asking about weather forecast ?
# 9                        Asking about weather forecast ?
# 10                      Asking about weather  forecast ?
# 11                      Asking about weather  forecast ?
# 12                       Asking about weather forecast ?
# 13                       Asking about weather forecast ?
# 14                       Asking about weather forecast ?
# 15                       Asking about weather forecast ?
# 16     farmer asked about control measure for  white ...
# 17     farmer asked about control measure for  white ...
# 18                        Asking about weather forecast?
# 19                        Asking about weather forecast?
# 20                        Asking about weather forecast?
# 21                        Asking about weather forecast?
# 22                Asking about weather forecast Tahsil ?
# 23                Asking about weather forecast Tahsil ?
# 24                        Asking about weather forecast?
# 25                        Asking about weather forecast?
# 26                   ASKING ABOUT WEATHER REPORT TAHSIL?
# 27                   ASKING ABOUT WEATHER REPORT TAHSIL?
# 28                Asking about weather forecast Tahsil ?
# 29                Asking about weather forecast Tahsil ?
# ...                                                  ...
# 26080                    Asking about weather forecast ?
# 26081        ASKED ABOUT ATTACK OF WHITE FLY ON COTTON ?
# 26082         FARMER ASKED ABOUT MARKET RATE OF SOYBEAN?
# 26083                     Asking about weather forecast?
# 26084                    Asking about weather forecast ?
# 26085                 ASKING ABOUT SEED RATE OF TOMATO ?
# 26086                   Asking about weather  forecast ?
# 26087                     Asking about weather forecast?
# 26088                     Asking about weather forecast?
# 26089                    Asking about weather forecast ?
# 26090                    Asking about weather forecast ?
# 26091                    Asking about weather forecast ?
# 26092                  ASKING ABOUT REDDNING OF COTTON ?
# 26093                    Asking about weather forecast ?
# 26094                     Asking about weather forecast?
# 26095                     Asking about weather forecast?
# 26096                       ATTACK OF POD BORER ON TUR ?
# 26097                     asked about attack of blight .
# 26098          FARMER ASKED ABOUT MARKET RATE OF GRAM  ?
# 26099                        Asked About SMS Activation?
# 26100                     Asking about weather forecast?
# 26101                 ASKED ABOUT MARKET RATE OF GRAM  ?
# 26102              ASKED ABOUT MARKET RATE OF SOYABEAN ?
# 26103                               SOYBEAN MARKET RATE?
# 26104         Attack of Jassids/Leaf hoppers on chilli ?
# 26105                               VARIETIES OF WHEAT ?
# 26106                     Asking about weather forecast?
# 26107                          Attack of wilt on cotton?
# 26108                     Asking about weather forecast?
# 26109                               VARIETIES OF WHEAT ?
#
#                                                   KCCAns
# 0      This week partially weather is CLOUDY and Poss...
# 1      This week partially weather is CLOUDY and Poss...
# 2      This week partially weather is CLOUDY and Poss...
# 3      This week partially weather is CLOUDY and Poss...
# 4      TAHSIL WEATHER REPORT-THIS WEEK WEATHER IS CLO...
